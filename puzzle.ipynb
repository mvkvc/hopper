# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("puzzle.csv", header=None, names=["x", "y"])

# %%
df.value_counts()[0:5]
# Out:
# x          y
#  0.397150   2.113629    101
#  0.715182   0.502910      2
# -0.388084   1.991229      2
#  0.690307   0.047801      2
# -0.065908  -0.672521      2
# dtype: int64

# %%
plt.scatter(df.x, df.y)

# %%
plt.scatter(df.y, df.x)
